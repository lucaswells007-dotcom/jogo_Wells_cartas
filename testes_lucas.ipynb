# %%
import os
from google import genai
from google.genai import types
from google.genai.errors import ClientError

GEMINI_API_KEY  =  os.environ.get("GEMINI_API_KEY")

def generate(input_text: str = "What is the capital of France?",):
    client = genai.Client(
        api_key=GEMINI_API_KEY,
    )

    model = "gemini-3-flash-preview"
    contents = [
        types.Content(
            role="user",
            parts=[
                types.Part.from_text(text=input_text),
            ],
        ),
    ]
        
    generate_content_config = types.GenerateContentConfig(
        # Set thinking to MINIMAL or LOW to save thousands of background tokens
        thinking_config=types.ThinkingConfig(
            thinking_level="MINIMAL",
        ),
        # Hard ceiling on combined thinking + output tokens to prevent quota drainage
        max_output_tokens=1024, 
        tools= None,
    )

    try:
        for chunk in client.models.generate_content_stream(
            model=model,
            contents=contents,
            config=generate_content_config,
        ):
            if text := chunk.text:
                print(text, end="")
        print() 
        
    except ClientError as e:
        print(f"\n[API Error]: {e}")


generate("Quem ganhou o jogo da argentina e austria? nessa copa de 2026")
# Out:
# Houve um pequeno equívoco na sua pergunta: a **Copa do Mundo de 2026 ainda não aconteceu**. Ela será realizada entre junho e julho de 2026, sediada por Estados Unidos, México e Canadá.
#
# Além disso, a **Áustria não se classificou** para a Copa de 2026 até o momento, pois as eliminatórias europeias ainda estão em andamento (ou sequer começaram em algumas regiões).
#
# É possível que você esteja se referindo a:
#
# 1.  **Um jogo de videogame (como FIFA/FC 24 ou 25):** Se você viu esse resultado em uma simulação ou vídeo de YouTube, foi algo fictício.
# 2.  **Um amistoso recente:** Argentina e Áustria não se enfrentaram recentemente no futebol masculino profissional.
# 3.  **Outra competição:** Talvez você tenha confundido o país (como Austrália, com quem a Argentina jogou na Copa de 2022).
#
# **Na Copa de 2022 (Catar):**
# A Argentina jogou contra a **Austrália** nas oitavas de final e **venceu por 2 a 1**.
#
# Se você viu essa notícia em algum lugar hoje, provavelmente é uma previsão, uma simulação de computador ou uma "fake news", já que o torneio real só daqui a dois anos.

# %%
GEMINI_API_KEY     =  os.environ.get("GEMINI_API_KEY")
GEMINI_API_KEY
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 GEMINI_API_KEY     =  os.environ.get("GEMINI_API_KEY")
#       2 GEMINI_API_KEY
#
# NameError: name 'os' is not defined
